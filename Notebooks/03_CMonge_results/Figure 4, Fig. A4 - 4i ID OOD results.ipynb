# %%
import yaml
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from pathlib import Path

# %%
default_colors = {
    "indigo": "#332288",
    "cyan": "#88CCEE",
    "teal": "#44AA99",
    "green": "#117733",
    "olive": "#999933",
    "sand": "#DDCC77",
    "rose": "#CC6677",
    "wine": "#882255",
    "purple": "#AA4499",
    "grey": "#DDDDDD",
}


ID_model_color_dict = {
    "Monge (1 cond.)": default_colors["wine"],
    "Identity": default_colors["sand"],
    "CMonge-MoA (33 cond.)": default_colors["cyan"],
    "CMonge-RDkit (33 cond.)": default_colors["teal"],
    "Monge-ID (33 cond.)": default_colors["purple"],
}

OOD_model_color_dict = {
    "Monge (1 cond.)": default_colors["wine"],
    "Identity": default_colors["sand"],
    "CMonge-MoA (32 cond.)": default_colors["cyan"],
    "CMonge-RDkit (32 cond.)": default_colors["teal"],
    "Monge-OOD (32 cond.)": default_colors["purple"],
}


ID_rename_dict = {"Identity": "Identity", 
               "Monge": "Monge (1 cond.)", 
               "Monge-ID": "Monge-ID (33 cond.)", 
               "CMonge-RDkit": "CMonge-RDkit (33 cond.)", 
               "CMonge-MoA": "CMonge-MoA (33 cond.)"}

OOD_rename_dict = {"Identity": "Identity", 
               "Monge": "Monge (1 cond.)", 
               "Monge-OOD": "Monge-OOD (32 cond.)", 
               "CMonge-RDkit": "CMonge-RDkit (32 cond.)", 
               "CMonge-MoA": "CMonge-MoA (32 cond.)"}

# %%
matplotlib.style.use("fivethirtyeight")
matplotlib.pyplot.rcParams['savefig.facecolor'] = 'white'
sns.set_style("whitegrid")

matplotlib.rcParams['font.family'] = "monospace"
matplotlib.rcParams['figure.dpi'] = 300
sns.set_context("poster")

# %%
fig_dir = "/Users/alicedriessen/Box/otperturb/alice_exp/figures/4i_"

# %% [markdown]
# # CMonge OOD

# %%
with open("/Users/alicedriessen/Box/otperturb/datasets/4i/drugs.txt", "r") as f:
    drugs = f.readlines()
drugs = [d.strip() for d in drugs]

settings = ["homogeneous", "CMonge-ood", "identity", "within condition"]
len(drugs)
# Out:
# 35

# %%
# base_dir = Path("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_ood/")
# all_mean_metrics = []
# for embedding in ["moa", "rdkit"]:
#     for drug in drugs:
#         if drug in ["vemurafenib_cobimetinib", "pomalidomide_carfilzomib_dexamethasone"]: # Excluded because there are no single treatments for either one available
#             continue
#         with open(base_dir / embedding / drug / "logs.yaml", "r") as file:
#             logs = yaml.safe_load(file)
#         print(embedding, drug, len(logs["experiments"]))

#         for i, setting in enumerate(settings):
#             mean_stats = {k: v["mean_statistics"] for k, v in logs["experiments"][i]["valid-set"].items()}
#             mean_stats = pd.DataFrame(mean_stats).T
#             mean_stats["eval_setting"] = setting
#             mean_stats["ood_drug"] = drug
#             mean_stats["embedding"] = embedding
            
#             all_mean_metrics.append(mean_stats)
            
# res = pd.concat(all_mean_metrics).reset_index().rename(columns={"index": "drug"})
# res.to_csv("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_ood/mean_results.csv")

# %% [markdown]
# # CMonge homogeneous

# %%
# all_mean_metrics = []
# settings = ["Cmonge-homogeneous", "identity"] + ["within condition"]*33
# with open("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_id/cmonge_homo_moa.yml", "r") as file:
#         logs = yaml.safe_load(file)
# print(len(logs["experiments"]))

# for i, setting in enumerate(settings):
#     mean_stats = {k: v["mean_statistics"] for k, v in logs["experiments"][i]["valid-set"].items()}
#     mean_stats = pd.DataFrame(mean_stats).T
#     mean_stats["eval_setting"] = setting
#     mean_stats["embedding"] = "moa"
    
#     all_mean_metrics.append(mean_stats)

# with open("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_id/cmonge_homo_rdkit.yml", "r") as file:
#         logs = yaml.safe_load(file)
# print(len(logs["experiments"]))

# for i, setting in enumerate(settings):
#     mean_stats = {k: v["mean_statistics"] for k, v in logs["experiments"][i]["valid-set"].items()}
#     mean_stats = pd.DataFrame(mean_stats).T
#     mean_stats["eval_setting"] = setting
#     mean_stats["embedding"] = "rdkit"
    
#     all_mean_metrics.append(mean_stats)

# res = pd.concat(all_mean_metrics).reset_index().rename(columns={"index": "drug"})
# res.to_csv("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_id/homogeneous_mean_results.csv")

# %% [markdown]
# # Monge - leave one condition out (OOD)

# %%
# with open("/Users/alicedriessen/Box/otperturb/datasets/4i/drugs.txt", "r") as f:
#     drugs = f.readlines()
# drugs = [d.strip() for d in drugs]

# settings = ["Monge-ood", "identity"]

# %%
# base_dir = Path("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_ood/monge/")
# all_mean_metrics = []
# for drug in drugs:
#     if drug in ["vemurafenib_cobimetinib", "pomalidomide_carfilzomib_dexamethasone"]: # Excluded because there are no single treatments for either one available
#         continue
#     with open(base_dir / drug / "logs.yaml", "r") as file:
#         logs = yaml.safe_load(file)
#     print(drug, len(logs["experiments"]))

#     for i, setting in enumerate(settings):
#         mean_stats = {drug: logs["experiments"][i]['mean_statistics']}
#         mean_stats = pd.DataFrame(mean_stats).T
#         mean_stats["eval_setting"] = setting
#         mean_stats["ood_drug"] = drug
        
#         all_mean_metrics.append(mean_stats)
            
# res = pd.concat(all_mean_metrics).reset_index().rename(columns={"index": "drug"})
# res.to_csv("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_ood/monge_mean_results.csv")

# %% [markdown]
# # Monge one model all conditions (ID)

# %%
with open("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_id/one_model_logs.yml", "r") as file:
    logs = yaml.safe_load(file)

# %%
len(logs["experiments"])
# Out:
# 84

# %%
drugs = [logs["experiments"][i]["drug"] for i in range(len(logs["experiments"]))]
monge_id_res = [pd.DataFrame(logs["experiments"][i]["mean_statistics"], index=[drugs[i]]) for i in range(18, len(logs["experiments"]))]
monge_id_res = pd.concat(monge_id_res)
monge_id_res["eval_setting"] = ["Monge-id", "Identity"] * 33
monge_id_res = monge_id_res.reset_index(drop=False).rename(columns={"index": "drug"})
monge_id_res = monge_id_res[monge_id_res["drug"]!="train"]

# %%
monge_id_res
# Out:
#                        drug  mean_wasserstein  mean_mmd  mean_sinkhorn div  \
# 0                 cisplatin          2.395193  0.011070           1.856728
# 1                 cisplatin          2.367384  0.009136           1.827592
# 2        cisplatin_olaparib          2.511764  0.013047           1.975483
# 3        cisplatin_olaparib          2.477684  0.012876           1.941226
# 4                crizotinib          4.179381  0.059255           3.646260
# ..                      ...               ...       ...                ...
# 61  trametinib_panobinostat          2.849569  0.051127           2.312716
# 62              ulixertinib          3.153677  0.055855           2.614381
# 63              ulixertinib          3.134075  0.057428           2.594367
# 64                vindesine          2.680823  0.015790           2.146414
# 65                vindesine          2.682748  0.018658           2.147505
#
#     mean_monge_gap  mean_drug_signature   mean_r2 eval_setting
# 0        11.593407             0.598814  0.415631     Monge-id
# 1        11.651654             0.540295  0.497943     Identity
# 2        11.694214             0.684476  0.309733     Monge-id
# 3        11.685173             0.642715  0.261228     Identity
# 4        11.741918             2.925568  0.007833     Monge-id
# ..             ...                  ...       ...          ...
# 61       11.440889             1.495717  0.290165     Identity
# 62       11.495801             1.920245  0.089683     Monge-id
# 63       11.493051             1.822917  0.265001     Identity
# 64       11.628006             0.753616  0.415898     Monge-id
# 65       11.572247             0.831109  0.313361     Identity
#
# [66 rows x 8 columns]

# %%
len(monge_id_res["drug"].unique())
# Out:
# 33

# %% [markdown]
# # Baselines

# %% [markdown]
# ## Monge one model per condition

# %%
with open("/Users/alicedriessen/Box/otperturb/benedek-archive/ot-perturb/logs/4i/test_monge_new.json", "r") as file:
    logs = yaml.safe_load(file)

# %%
drugs = [logs["experiments"][i]["drug"] for i in range(len(logs["experiments"]))]
monge_res = [pd.DataFrame(logs["experiments"][i]["mean_statistics"], index=[drugs[i]]*5) for i in range(len(logs["experiments"]))]
monge_res = pd.concat(monge_res).reset_index(drop=False).rename(columns={'index':"drug"})
monge_res["eval_setting"] = "Monge"
monge_res = monge_res[monge_res["drug"].isin(monge_id_res["drug"].unique())]

# %%
len(monge_res["drug"].unique())
# Out:
# 33

# %% [markdown]
# ## Identity

# %%
with open("/Users/alicedriessen/Box/otperturb/benedek-archive/ot-perturb/logs/4i/test_identity_new.json", "r") as file:
    logs = yaml.safe_load(file)

# %%
drugs = [logs["experiments"][i]["drug"] for i in range(len(logs["experiments"]))]
identity_res = [pd.DataFrame(logs["experiments"][i]["mean_statistics"], index=[drugs[i]]*5) for i in range(len(logs["experiments"]))]
identity_res = pd.concat(identity_res).reset_index(drop=False).rename(columns={'index':"drug"})
identity_res["eval_setting"] = "Identity"
identity_res = identity_res[identity_res["drug"].isin(monge_id_res["drug"].unique())]

# %%
len(identity_res["drug"].unique())
# Out:
# 33

# %% [markdown]
# # All results

# %%
res = pd.read_csv("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_ood/mean_results.csv", index_col=0)
res["drug_combi"] = [len(d.split("_"))>1 for d in res["drug"]]
res = res[res["eval_setting"]!="homogeneous"]

homogeneous_res = pd.read_csv("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_id/homogeneous_mean_results.csv", index_col=0)
h_res = homogeneous_res[homogeneous_res["eval_setting"]=="Cmonge-homogeneous"]

monge_ood_res = pd.read_csv("/Users/alicedriessen/Box/otperturb/alice_exp/models/4i_ood/monge_mean_results.csv", index_col=0)

res = pd.concat([res, h_res, monge_ood_res, monge_id_res])
res[~res["drug"].isin(["vemurafenib_cobimetinib", "pomalidomide_carfilzomib_dexamethasone"])]
res[~res["ood_drug"].isin(["vemurafenib_cobimetinib", "pomalidomide_carfilzomib_dexamethasone"])]
res["drug_combi"] = [len(d.split("_"))>1 for d in res["drug"]]

res["Model"] = None
res["split"] = None
res.loc[(res["embedding"]=="moa")&(res["eval_setting"]=="CMonge-ood"), ["Model", "split"]] = ("CMonge-MoA", "OOD")
res.loc[(res["embedding"]=="moa")&(res["eval_setting"]=="Cmonge-homogeneous"), ["Model", "split"]] = ("CMonge-MoA", "ID")

res.loc[(res["embedding"]=="rdkit")&(res["eval_setting"]=="CMonge-ood"), ["Model", "split"]] = ("CMonge-RDkit", "OOD")
res.loc[(res["embedding"]=="rdkit")&(res["eval_setting"]=="Cmonge-homogeneous"), ["Model", "split"]] = ("CMonge-RDkit", "ID")

res.loc[res["eval_setting"]=="Monge-id", ["Model", "split"]] = ("Monge-ID", "ID")
res.loc[res["eval_setting"]=="Monge-ood", ["Model", "split"]] = ("Monge-OOD", "OOD")
# res.loc[res["eval_setting"]=="within condition", "Model"] = "Within condition"

res = res[res["eval_setting"]!="within condition"]
res = res[res["eval_setting"]!="Identity"]
res = res[res["eval_setting"]!="identity"]

# %%
res
# Out:
#                         drug  mean_wasserstein  mean_mmd  mean_sinkhorn div  \
# 33                 cisplatin          2.306689  0.010304           1.755848
# 69        cisplatin_olaparib          2.358715  0.009750           1.808513
# 105               crizotinib          3.555755  0.044072           3.005959
# 141               dabrafenib          2.255459  0.011747           1.704944
# 177              dacarbazine          2.345079  0.013032           1.795207
# ..                       ...               ...       ...                ...
# 56      trametinib_erlotinib          2.629958  0.033386           2.093489
# 58    trametinib_midostaurin          2.885979  0.030991           2.350081
# 60   trametinib_panobinostat          2.727184  0.035954           2.190698
# 62               ulixertinib          3.153677  0.055855           2.614381
# 64                 vindesine          2.680823  0.015790           2.146414
#
#      mean_monge_gap  mean_drug_signature   mean_r2 eval_setting  \
# 33        11.677592             0.534577  0.572434   CMonge-ood
# 69        11.652626             0.512958  0.466014   CMonge-ood
# 105       11.834755             2.074579  0.475721   CMonge-ood
# 141       11.557710             0.576442  0.676360   CMonge-ood
# 177       11.693209             0.690394  0.416813   CMonge-ood
# ..              ...                  ...       ...          ...
# 56        11.635617             1.235834  0.663413     Monge-id
# 58        11.585241             1.259380  0.544634     Monge-id
# 60        11.479805             1.244938  0.603302     Monge-id
# 62        11.495801             1.920245  0.089683     Monge-id
# 64        11.628006             0.753616  0.415898     Monge-id
#
#                ood_drug embedding  drug_combi       Model split
# 33            cisplatin       moa       False  CMonge-MoA   OOD
# 69   cisplatin_olaparib       moa        True  CMonge-MoA   OOD
# 105          crizotinib       moa       False  CMonge-MoA   OOD
# 141          dabrafenib       moa       False  CMonge-MoA   OOD
# 177         dacarbazine       moa       False  CMonge-MoA   OOD
# ..                  ...       ...         ...         ...   ...
# 56                  NaN       NaN        True    Monge-ID    ID
# 58                  NaN       NaN        True    Monge-ID    ID
# 60                  NaN       NaN        True    Monge-ID    ID
# 62                  NaN       NaN       False    Monge-ID    ID
# 64                  NaN       NaN       False    Monge-ID    ID
#
# [198 rows x 13 columns]

# %%
len(res["drug"].unique())
# Out:
# 33

# %%
monge_res
# Out:
#                                     drug  mean_wasserstein  mean_mmd  \
# 0                              cisplatin          2.240693  0.007778
# 5                     cisplatin_olaparib          2.279414  0.008010
# 10                            crizotinib          2.724159  0.010781
# 15                            dabrafenib          2.167839  0.007661
# 20                           dacarbazine          2.222479  0.007877
# 25                             dasatinib          2.695207  0.009536
# 30                            decitabine          2.310464  0.008223
# 35                         dexamethasone          2.377800  0.008939
# 40                             erlotinib          2.279770  0.007837
# 45                            everolimus          2.343144  0.007880
# 50                           hydroxyurea          2.355961  0.008674
# 55                              imatinib          2.437124  0.008545
# 60                              ixazomib          2.684861  0.009446
# 65   ixazomib_lenalidomide_dexamethasone          2.398817  0.008624
# 70                          lenalidomide          2.145334  0.007315
# 75                             melphalan          2.223985  0.008106
# 80                           midostaurin          2.239703  0.008232
# 85                               mln2480          2.162200  0.007686
# 90                              olaparib          2.331525  0.008171
# 95                            paclitaxel          2.714234  0.010063
# 100                          palbociclib          2.288366  0.008303
# 105                         panobinostat          2.213333  0.008934
# 115                          regorafenib          2.238993  0.009276
# 120                            sorafenib          2.260113  0.007723
# 125                        staurosporine          3.014516  0.011780
# 130                         temozolomide          2.303479  0.007614
# 135                           trametinib          2.058955  0.007229
# 140                trametinib_dabrafenib          2.092224  0.007592
# 145                 trametinib_erlotinib          2.037657  0.007030
# 150               trametinib_midostaurin          2.472009  0.009490
# 155              trametinib_panobinostat          2.106062  0.008115
# 160                          ulixertinib          2.220153  0.008553
# 170                            vindesine          2.451876  0.009151
#
#      mean_sinkhorn div  mean_monge_gap  mean_drug_signature   mean_r2  \
# 0             1.705432       11.687905             0.328795  0.895511
# 5             1.746893       11.760812             0.278758  0.921947
# 10            2.194651       12.524020             0.349548  0.993448
# 15            1.633139       11.523658             0.331609  0.943518
# 20            1.688417       11.889913             0.330537  0.863768
# 25            2.162524       12.874700             0.439148  0.975089
# 30            1.775088       11.684807             0.319224  0.863485
# 35            1.842051       11.705968             0.295957  0.964054
# 40            1.745542       11.780825             0.357316  0.913682
# 45            1.808663       11.887859             0.355558  0.965039
# 50            1.821554       11.594063             0.392598  0.902788
# 55            1.902040       12.057556             0.398392  0.985318
# 60            2.150899       12.296351             0.387136  0.977306
# 65            1.865515       12.126184             0.360715  0.963880
# 70            1.612034       11.597862             0.261293  0.927434
# 75            1.691976       11.727557             0.325691  0.871084
# 80            1.705254       11.630159             0.348895  0.964705
# 85            1.628171       11.641402             0.257029  0.983690
# 90            1.796933       11.754091             0.334134  0.834320
# 95            2.179811       12.329840             0.434765  0.985937
# 100           1.755367       11.853793             0.288522  0.934827
# 105           1.680471       11.617587             0.336061  0.954439
# 115           1.705695       11.711236             0.264309  0.985659
# 120           1.726248       11.920601             0.285988  0.970963
# 125           2.492307       12.512013             0.542022  0.994557
# 130           1.769522       11.705453             0.294332  0.937020
# 135           1.524544       11.610623             0.242129  0.986348
# 140           1.554893       11.560814             0.267039  0.985025
# 145           1.503707       11.626454             0.206608  0.991446
# 150           1.939461       11.663485             0.420679  0.969851
# 155           1.572558       11.436376             0.276256  0.985505
# 160           1.685097       11.642818             0.264563  0.992770
# 170           1.920841       11.614938             0.390576  0.926007
#
#     eval_setting
# 0          Monge
# 5          Monge
# 10         Monge
# 15         Monge
# 20         Monge
# 25         Monge
# 30         Monge
# 35         Monge
# 40         Monge
# 45         Monge
# 50         Monge
# 55         Monge
# 60         Monge
# 65         Monge
# 70         Monge
# 75         Monge
# 80         Monge
# 85         Monge
# 90         Monge
# 95         Monge
# 100        Monge
# 105        Monge
# 115        Monge
# 120        Monge
# 125        Monge
# 130        Monge
# 135        Monge
# 140        Monge
# 145        Monge
# 150        Monge
# 155        Monge
# 160        Monge
# 170        Monge

# %% [markdown]
# # In distribution results

# %%
monge_res = monge_res.drop_duplicates()
identity_res = identity_res.drop_duplicates()

monge_res["drug_combi"] = [len(d.split("_"))>1 for d in monge_res["drug"]]
identity_res["drug_combi"] = [len(d.split("_"))>1 for d in identity_res["drug"]]



mean_monge_r2 = monge_res["mean_r2"].mean()
mean_monge_single_r2 = monge_res.loc[~monge_res["drug_combi"], "mean_r2"].mean()
mean_monge_combi_r2 = monge_res.loc[monge_res["drug_combi"], "mean_r2"].mean()

mean_monge_emd = monge_res["mean_wasserstein"].mean()
mean_monge_single_emd = monge_res.loc[~monge_res["drug_combi"], "mean_wasserstein"].mean()
mean_monge_combi_emd = monge_res.loc[monge_res["drug_combi"], "mean_wasserstein"].mean()

mean_identity_r2 = identity_res["mean_r2"].mean()
mean_identity_single_r2 = identity_res.loc[~identity_res["drug_combi"], "mean_r2"].mean()
mean_identity_combi_r2 = identity_res.loc[identity_res["drug_combi"], "mean_r2"].mean()

mean_identity_emd = identity_res["mean_wasserstein"].mean()
mean_identity_single_emd = identity_res.loc[~identity_res["drug_combi"], "mean_wasserstein"].mean()
mean_identity_combi_emd = identity_res.loc[identity_res["drug_combi"], "mean_wasserstein"].mean()

mean_identity_mmd = identity_res["mean_mmd"].mean()
mean_identity_single_mmd = identity_res.loc[~identity_res["drug_combi"], "mean_mmd"].mean()
mean_identity_combi_mmd = identity_res.loc[identity_res["drug_combi"], "mean_mmd"].mean()

# %%
ID_res = res[res["split"].isin(["ID"])].reset_index(drop=True)
sns.boxenplot(data=ID_res, y="Model", x="mean_r2", hue="Model", order=["Monge-ID", "CMonge-MoA","CMonge-RDkit"])
plt.title("In distribution results, all drugs")
plt.xlabel("$R^2$")
plt.savefig(f"{fig_dir}R2_ID_all_drugs.pdf", bbox_inches="tight")

# %%
eval_settings = ["Monge-ID (33 cond.)", "CMonge-MoA (33 cond.)","CMonge-RDkit (33 cond.)"]
ID_res = ID_res.replace(ID_rename_dict)
# Out:
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2980754882.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ID_res = ID_res.replace(ID_rename_dict)

# %%
ID_res["Model"].unique()
# Out:
# array(['CMonge-MoA (33 cond.)', 'CMonge-RDkit (33 cond.)',
#        'Monge-ID (33 cond.)'], dtype=object)

# %%
fig, axes = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(7, 10))

sns.boxenplot(data=ID_res, y="Model", x="mean_r2", hue="Model", ax=axes[0], order=eval_settings, palette=ID_model_color_dict)
sns.boxenplot(data=ID_res.loc[~ID_res["drug_combi"], :], y="Model", x="mean_r2", hue="Model", ax=axes[1], palette=ID_model_color_dict)
sns.boxenplot(data=ID_res.loc[ID_res["drug_combi"], :], y="Model", x="mean_r2", hue="Model", ax=axes[2], palette=ID_model_color_dict)

axes[0].axvline(x=mean_monge_r2, label="Monge (1 cond.)", c=ID_model_color_dict["Monge (1 cond.)"])
axes[1].axvline(x=mean_monge_single_r2, label="Monge (1 cond.)", c=ID_model_color_dict["Monge (1 cond.)"])
axes[2].axvline(x=mean_monge_combi_r2, label="Monge (1 cond.)", c=ID_model_color_dict["Monge (1 cond.)"])

axes[0].axvline(x=mean_identity_r2, label="Identity", c=ID_model_color_dict["Identity"])
axes[1].axvline(x=mean_identity_single_r2, label="Identity", c=ID_model_color_dict["Identity"])
axes[2].axvline(x=mean_identity_combi_r2, label="Identity", c=ID_model_color_dict["Identity"])

fig.suptitle("In distribution results")
axes[0].set_title("all drugs", fontweight="normal")
axes[1].set_title("single drugs", fontweight="normal")
axes[2].set_title("combi drugs", fontweight="normal")

axes[0].set_xlabel("")
axes[1].set_xlabel("")
axes[2].set_xlabel("mean $R^2$ per drug")
# axes[0].tick_params(labelsize=12)
# axes[1].tick_params(labelsize=12)
# axes[2].tick_params(labelsize=12)

axes[0].set_ylabel("")
axes[1].set_ylabel("Model")
axes[2].set_ylabel("")

axes[0].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
axes[1].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
axes[2].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])

axes[0].text(-0.03, 2.4, "n=33", fontsize=12)
axes[1].text(-0.03, 2.4, "n=33", fontsize=12)
axes[2].text(-0.03, 2.4, "n=33", fontsize=12)

plt.savefig(f"{fig_dir}R2_ID_all_drugs.pdf", bbox_inches="tight")
# Out:
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2086659042.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2086659042.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2086659042.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])

# %%
fig, axes = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(7, 10))

sns.boxenplot(data=ID_res, y="Model", x="mean_wasserstein", hue="Model", ax=axes[0], order=eval_settings, palette=ID_model_color_dict)
sns.boxenplot(data=ID_res.loc[~ID_res["drug_combi"], :], y="Model", x="mean_wasserstein", hue="Model", ax=axes[1], palette=ID_model_color_dict)
sns.boxenplot(data=ID_res.loc[ID_res["drug_combi"], :], y="Model", x="mean_wasserstein", hue="Model", ax=axes[2], palette=ID_model_color_dict)

axes[0].axvline(x=mean_monge_emd, label="Monge (1 cond.)", c=ID_model_color_dict["Monge (1 cond.)"])
axes[1].axvline(x=mean_monge_single_emd, label="Monge (1 cond.)", c=ID_model_color_dict["Monge (1 cond.)"])
axes[2].axvline(x=mean_monge_combi_emd, label="Monge (1 cond.)", c=ID_model_color_dict["Monge (1 cond.)"])

axes[0].axvline(x=mean_identity_emd, label="Identity", c=ID_model_color_dict["Identity"])
axes[1].axvline(x=mean_identity_single_emd, label="Identity", c=ID_model_color_dict["Identity"])
axes[2].axvline(x=mean_identity_combi_emd, label="Identity", c=ID_model_color_dict["Identity"])


fig.suptitle("In distribution results")
axes[0].set_title("all drugs", fontweight="normal")
axes[1].set_title("single drugs", fontweight="normal")
axes[2].set_title("combi drugs", fontweight="normal")

axes[0].set_xlabel("")
axes[1].set_xlabel("",)
axes[2].set_xlabel("mean Wasserstein distance per drug", fontsize=20)
# axes[0].tick_params(labelsize=12)
# axes[1].tick_params(labelsize=12)
# axes[2].tick_params(labelsize=12)

axes[0].set_ylabel("")
axes[1].set_ylabel("Model")
axes[2].set_ylabel("")

axes[0].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
axes[1].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
axes[2].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])

axes[0].text(6.1, -0.2, "n=33", fontsize=12)
axes[1].text(6.1, -0.2, "n=33", fontsize=12)
axes[2].text(6.1, -0.2, "n=33", fontsize=12)

plt.savefig(f"{fig_dir}EMD_ID_all_drugs.pdf", bbox_inches="tight")
# Out:
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/509927968.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/509927968.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/509927968.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_yticklabels(["Monge-ID\n(33 cond.)", "CMonge-MoA\n(33 cond.)","CMonge-RDkit\n(33 cond.)"])

# %% [markdown]
# # Out of distribution results

# %%
eval_settings = ["Monge-OOD (32 cond.)", "CMonge-MoA (32 cond.)","CMonge-RDkit (32 cond.)"]

# %%
OOD_res = res[res["split"].isin(["OOD"])].reset_index(drop=True)
sns.boxenplot(data=OOD_res, y="Model", x="mean_r2", hue="Model", order=["Monge-OOD", "CMonge-MoA","CMonge-RDkit"])
plt.title("Out of distribution results, all drugs")
plt.xlabel("$R^2$")
plt.savefig(f"{fig_dir}R2_OOD_all_drugs.pdf", bbox_inches="tight")

# %%
OOD_res = OOD_res.replace(OOD_rename_dict).reset_index(drop=True)
OOD_res
# Out:
#                        drug  mean_wasserstein  mean_mmd  mean_sinkhorn div  \
# 0                 cisplatin          2.306689  0.010304           1.755848
# 1        cisplatin_olaparib          2.358715  0.009750           1.808513
# 2                crizotinib          3.555755  0.044072           3.005959
# 3                dabrafenib          2.255459  0.011747           1.704944
# 4               dacarbazine          2.345079  0.013032           1.795207
# ..                      ...               ...       ...                ...
# 94     trametinib_erlotinib          2.649972  0.033879           2.100046
# 95   trametinib_midostaurin          2.953146  0.029598           2.403428
# 96  trametinib_panobinostat          2.701848  0.034495           2.152171
# 97              ulixertinib          3.127784  0.057888           2.577459
# 98                vindesine          2.670267  0.015058           2.120557
#
#     mean_monge_gap  mean_drug_signature   mean_r2 eval_setting  \
# 0        11.677592             0.534577  0.572434   CMonge-ood
# 1        11.652626             0.512958  0.466014   CMonge-ood
# 2        11.834755             2.074579  0.475721   CMonge-ood
# 3        11.557710             0.576442  0.676360   CMonge-ood
# 4        11.693209             0.690394  0.416813   CMonge-ood
# ..             ...                  ...       ...          ...
# 94       11.578692             1.280660  0.613751    Monge-ood
# 95       11.594159             1.278964  0.516168    Monge-ood
# 96       11.495450             1.262183  0.577078    Monge-ood
# 97       11.559109             1.926990  0.067145    Monge-ood
# 98       11.642492             0.787020  0.367599    Monge-ood
#
#                    ood_drug embedding  drug_combi                  Model split
# 0                 cisplatin       moa       False  CMonge-MoA (32 cond.)   OOD
# 1        cisplatin_olaparib       moa        True  CMonge-MoA (32 cond.)   OOD
# 2                crizotinib       moa       False  CMonge-MoA (32 cond.)   OOD
# 3                dabrafenib       moa       False  CMonge-MoA (32 cond.)   OOD
# 4               dacarbazine       moa       False  CMonge-MoA (32 cond.)   OOD
# ..                      ...       ...         ...                    ...   ...
# 94     trametinib_erlotinib       NaN        True   Monge-OOD (32 cond.)   OOD
# 95   trametinib_midostaurin       NaN        True   Monge-OOD (32 cond.)   OOD
# 96  trametinib_panobinostat       NaN        True   Monge-OOD (32 cond.)   OOD
# 97              ulixertinib       NaN       False   Monge-OOD (32 cond.)   OOD
# 98                vindesine       NaN       False   Monge-OOD (32 cond.)   OOD
#
# [99 rows x 13 columns]

# %%
eval_settings
# Out:
# ['Monge-OOD (32 cond.)', 'CMonge-MoA (32 cond.)', 'CMonge-RDkit (32 cond.)']

# %%
OOD_res["Model"].unique()
# Out:
# array(['CMonge-MoA (32 cond.)', 'CMonge-RDkit (32 cond.)',
#        'Monge-OOD (32 cond.)'], dtype=object)

# %%
OOD_model_color_dict
# Out:
# {'Monge (1 cond.)': '#882255',
#  'Identity': '#DDCC77',
#  'CMonge-MoA (32 cond.)': '#88CCEE',
#  'CMonge-RDkit (32 cond.)': '#44AA99',
#  'Monge-OOD (32 cond.)': '#AA4499'}

# %%
fig, axes = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(7, 10))

sns.boxenplot(data=OOD_res, y="Model", x="mean_r2", hue="Model", ax=axes[0], order=eval_settings      , palette=OOD_model_color_dict)
sns.boxenplot(data=OOD_res.loc[~OOD_res["drug_combi"], :], y="Model", x="mean_r2", hue="Model", ax=axes[1], palette=OOD_model_color_dict)
sns.boxenplot(data=OOD_res.loc[OOD_res["drug_combi"], :], y="Model", x="mean_r2", hue="Model", ax=axes[2] , palette=OOD_model_color_dict)

axes[0].axvline(x=mean_identity_r2, label="Identity", c=ID_model_color_dict["Identity"])
axes[1].axvline(x=mean_identity_single_r2, label="Identity", c=ID_model_color_dict["Identity"])
axes[2].axvline(x=mean_identity_combi_r2, label="Identity", c=ID_model_color_dict["Identity"])

fig.suptitle("Out of distribution results")
axes[0].set_title("all drugs",  fontweight="normal")
axes[1].set_title("single drugs", fontweight="normal")
axes[2].set_title("combi drugs", fontweight="normal")

axes[0].set_xlabel("")
axes[1].set_xlabel("")
axes[2].set_xlabel("mean $R^2$ per drug")
# axes[0].tick_params(labelsize=12)
# axes[1].tick_params(labelsize=12)
# axes[2].tick_params(labelsize=12)

axes[0].set_ylabel("")
axes[1].set_ylabel("Model")
axes[2].set_ylabel("")

axes[0].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
axes[1].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
axes[2].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])

axes[0].text(0.86, -0.3, "n=33", fontsize=12)
axes[1].text(0.86, -0.3, "n=33", fontsize=12)
axes[2].text(0.86, -0.3, "n=33", fontsize=12)

plt.savefig(f"{fig_dir}R2_OOD_all_drugs.pdf", bbox_inches="tight")
# Out:
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2970358125.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2970358125.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2970358125.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])

# %%
fig, axes = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(7, 10))

sns.boxenplot(data=OOD_res, y="Model", x="mean_wasserstein", hue="Model", ax=axes[0], order=eval_settings      , palette=OOD_model_color_dict )
sns.boxenplot(data=OOD_res.loc[~OOD_res["drug_combi"], :], y="Model", x="mean_wasserstein", hue="Model", ax=axes[1], palette=OOD_model_color_dict )
sns.boxenplot(data=OOD_res.loc[OOD_res["drug_combi"], :], y="Model", x="mean_wasserstein", hue="Model", ax=axes[2] , palette=OOD_model_color_dict )

axes[0].axvline(x=mean_identity_emd, label="Identity", c=ID_model_color_dict["Identity"])
axes[1].axvline(x=mean_identity_single_emd, label="Identity", c=ID_model_color_dict["Identity"])
axes[2].axvline(x=mean_identity_combi_emd, label="Identity", c=ID_model_color_dict["Identity"])

fig.suptitle("Out of distribution results")

axes[0].set_title("all drugs",   fontweight="normal")
axes[1].set_title("single drugs", fontweight="normal")
axes[2].set_title("combi drugs", fontweight="normal")

axes[0].set_xlabel("")
axes[1].set_xlabel("")
axes[2].set_xlabel("mean Wasserstein distance per drug", fontsize=20)
# axes[0].tick_params(labelsize=12)
# axes[1].tick_params(labelsize=12)
# axes[2].tick_params(labelsize=12)

axes[0].set_ylabel("")
axes[1].set_ylabel("Model")
axes[2].set_ylabel("")

axes[0].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
axes[1].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
axes[2].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])

axes[0].text(6.6, -0.2, "n=33", fontsize=14)
axes[1].text(6.6, -0.2, "n=33", fontsize=14)
axes[2].text(6.6, -0.2, "n=33", fontsize=14)

plt.savefig(f"{fig_dir}EMD_OOD_all_drugs.pdf", bbox_inches="tight")
# Out:
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/110495696.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/110495696.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/110495696.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])

# %%
fig, axes = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(7, 10))

sns.boxenplot(data=OOD_res, y="Model", x="mean_mmd", hue="Model", ax=axes[0], order=eval_settings      , palette=OOD_model_color_dict )
sns.boxenplot(data=OOD_res.loc[~OOD_res["drug_combi"], :], y="Model", x="mean_mmd", hue="Model", ax=axes[1], palette=OOD_model_color_dict )
sns.boxenplot(data=OOD_res.loc[OOD_res["drug_combi"], :], y="Model", x="mean_mmd", hue="Model", ax=axes[2] , palette=OOD_model_color_dict )

axes[0].axvline(x=mean_identity_mmd, label="Identity", c=ID_model_color_dict["Identity"])
axes[1].axvline(x=mean_identity_single_mmd, label="Identity", c=ID_model_color_dict["Identity"])
axes[2].axvline(x=mean_identity_combi_mmd, label="Identity", c=ID_model_color_dict["Identity"])

fig.suptitle("Out of distribution results")

axes[0].set_title("all drugs",   fontweight="normal")
axes[1].set_title("single drugs", fontweight="normal")
axes[2].set_title("combi drugs", fontweight="normal")

axes[0].set_xlabel("")
axes[1].set_xlabel("")
axes[2].set_xlabel("Mean MMD per drug")
# axes[0].tick_params(labelsize=12)
# axes[1].tick_params(labelsize=12)
# axes[2].tick_params(labelsize=12)

axes[0].set_ylabel("")
axes[1].set_ylabel("Model")
axes[2].set_ylabel("")

axes[0].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
axes[1].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
axes[2].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])

axes[0].text(0.16, -0.2, "n=33", fontsize=14)
axes[1].text(0.16, -0.2, "n=33", fontsize=14)
axes[2].text(0.16, -0.2, "n=33", fontsize=14)

plt.savefig(f"{fig_dir}MMD_OOD_all_drugs.pdf", bbox_inches="tight")
# Out:
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2597198017.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2597198017.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
# /var/folders/02/gztwz1tj1051mtt_ykv6v7940000gn/T/ipykernel_57448/2597198017.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_yticklabels(["Monge-OOD\n(32 cond.)", "CMonge-MoA\n(32 cond.)","CMonge-RDkit\n(32 cond.)"])
